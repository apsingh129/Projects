# %% [markdown]
# ### Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading the Dataset

# %%
df=pd.read_csv("domain.csv")

# %%
df
# Out:
#              Date        PL  Username @Timestamp per day  \
# 0      02-01-2020     parao  rjaiswar         02-01-2020
# 1      02-01-2020     parao  sakoleka         02-01-2020
# 2      02-01-2020     parao  nthakull         02-01-2020
# 3      02-01-2020     parao  rajeyada         02-01-2020
# 4      02-01-2020     parao  ajayyada         02-01-2020
# ...           ...       ...       ...                ...
# 12782  26-10-2020  tripathy   marathe         26-10-2020
# 12783  26-10-2020  tripathy   pursani         26-10-2020
# 12784  27-10-2020     parao    cpawar         27-10-2020
# 12785  28-10-2020     parao    kuniyl         28-10-2020
# 12786  29-10-2020  tripathy  bpanchal         29-10-2020
#
#                     Task Name  Head Counts  Tool Time  User Active Time  \
# 0        RWOFSignReviewRepair            1     516.92            317.10
# 1        RWOFSignReviewRepair            1     515.40            402.32
# ...

# %%
df.describe()
# Out:
#        Head Counts     Tool Time  User Active Time     Idle Time  \
# count      12787.0  12787.000000      12787.000000  12787.000000
# mean           1.0    407.019471        246.782505    160.237066
# std            0.0    388.508621        251.747866    199.710548
# min            1.0      0.000000      -1679.520000      0.000000
# 25%            1.0    222.500000        120.075000     54.060000
# 50%            1.0    403.200000        224.960000    128.680000
# 75%            1.0    509.580000        326.670000    222.460000
# max            1.0  17811.870000       9387.030000  11178.870000
#
#        Kms Completed  Count of Tiles         Hours
# count   12787.000000    12787.000000  12787.000000
# mean       37.246320        9.820990      6.783785
# std        41.816708       11.169468      6.475118
# min         0.000000        1.000000      0.000000
# 25%         9.500000        2.000000      3.710000
# 50%        22.300000        6.000000      6.720000
# ...

# %%
df.isnull().sum()
# Out:
# Date                  0
# PL                    0
# Username              0
# @Timestamp per day    0
# Task Name             0
# Head Counts           0
# Tool Time             0
# User Active Time      0
# Idle Time             0
# Kms Completed         0
# Features              0
# Count of Tiles        0
# Hours                 0
# dtype: int64

# %% [markdown]
# ### Tool Time

# %%
plt.figure()
plt.plot(df["Tool Time"])

# %% [markdown]
# ### Tool Time Vs Kms Completed

# %%
plt.scatter(df["Tool Time"],df["Kms Completed"])
plt.xlabel("Tooltime")
plt.ylabel("kms Completed")
# Out:
# Text(0, 0.5, 'kms Completed')

# %% [markdown]
# ##### Here we can see the kms completed with Respect to Tool time.Here we can see when the Tool time was between 0 to 500.The kms completed was more , as the tool time is increasing the kms completed was less

# %%
df["Tool Time"].unique()
# Out:
# array([516.92, 515.4 , 497.35, ..., 107.48, 294.07,  29.05])

# %%
df["Kms Completed"].unique()
# Out:
# array([100.5, 126.5, 169.5, ..., 159.6, 194.6, 171.5])

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(df["Tool Time"])
# Out:
# C:\Users\91702\AppData\Roaming\Python\Python37\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Tool Time'>

# %% [markdown]
# ##### Boxplot are usually use to find the outliers in the dataset, Here we can see many outliers after 550 Tool time

# %%
sns.boxplot(df["Kms Completed"])
# Out:
# C:\Users\91702\AppData\Roaming\Python\Python37\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Kms Completed'>

# %%
df.head()
# Out:
#          Date     PL  Username @Timestamp per day             Task Name  \
# 0  02-01-2020  parao  rjaiswar         02-01-2020  RWOFSignReviewRepair
# 1  02-01-2020  parao  sakoleka         02-01-2020  RWOFSignReviewRepair
# 2  02-01-2020  parao  nthakull         02-01-2020  RWOFSignReviewRepair
# 3  02-01-2020  parao  rajeyada         02-01-2020  RWOFSignReviewRepair
# 4  02-01-2020  parao  ajayyada         02-01-2020  RWOFSignReviewRepair
#
#    Head Counts  Tool Time  User Active Time  Idle Time  Kms Completed  \
# 0            1     516.92            317.10     199.82          100.5
# 1            1     515.40            402.32     113.08          126.5
# 2            1     497.35            402.45      94.90          169.5
# 3            1     493.90            259.88     234.02          186.6
# 4            1     476.43            303.32     173.12          148.0
#
#   Features  Count of Tiles  Hours
# 0    1,145              25   8.62
# 1    1,545              33   8.59
# ...

# %%
df.drop(columns=["Head Counts"],inplace=True)

# %%
df.head()
# Out:
#          Date     PL  Username @Timestamp per day             Task Name  \
# 0  02-01-2020  parao  rjaiswar         02-01-2020  RWOFSignReviewRepair
# 1  02-01-2020  parao  sakoleka         02-01-2020  RWOFSignReviewRepair
# 2  02-01-2020  parao  nthakull         02-01-2020  RWOFSignReviewRepair
# 3  02-01-2020  parao  rajeyada         02-01-2020  RWOFSignReviewRepair
# 4  02-01-2020  parao  ajayyada         02-01-2020  RWOFSignReviewRepair
#
#    Tool Time  User Active Time  Idle Time  Kms Completed Features  \
# 0     516.92            317.10     199.82          100.5    1,145
# 1     515.40            402.32     113.08          126.5    1,545
# 2     497.35            402.45      94.90          169.5    1,285
# 3     493.90            259.88     234.02          186.6    1,332
# 4     476.43            303.32     173.12          148.0    1,368
#
#    Count of Tiles  Hours
# 0              25   8.62
# 1              33   8.59
# 2              46   8.29
# 3              49   8.23
# ...

# %% [markdown]
# ### Correlation are Basically use to find the relation between the features

# %%
df.corr()
# Out:
#                   Tool Time  User Active Time  Idle Time  Kms Completed  \
# Tool Time          1.000000          0.891721   0.821288       0.181844
# User Active Time   0.891721          1.000000   0.474153       0.235324
# Idle Time          0.821288          0.474153   1.000000       0.057111
# Kms Completed      0.181844          0.235324   0.057111       1.000000
# Count of Tiles     0.162294          0.211223   0.049460       0.978104
# Hours              1.000000          0.891722   0.821287       0.181839
#
#                   Count of Tiles     Hours
# Tool Time               0.162294  1.000000
# User Active Time        0.211223  0.891722
# Idle Time               0.049460  0.821287
# Kms Completed           0.978104  0.181839
# Count of Tiles          1.000000  0.162289
# Hours                   0.162289  1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### JointPlot

# %%
sns.jointplot(x="Idle Time",y="Kms Completed",data=df,kind="reg")

# %% [markdown]
# #### when the IDle time was less the kms completed was more

# %%
sns.boxplot(df["Idle Time"])
# Out:
# C:\Users\91702\AppData\Roaming\Python\Python37\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Idle Time'>

# %%
sns.jointplot(x="User Active Time",y="Kms Completed",data=df,kind="reg")

# %%
sns.countplot(x="PL",data=df)
# Out:
# <AxesSubplot:xlabel='PL', ylabel='count'>

# %%
df["PL"].unique()
# Out:
# array(['parao', 'prasr', 'ssaini', 'tripathy', 'lpinto', 'akrai',
#        'apathak', 'srepai', 'apandit', 'vchavan', 'shrjadha', 'jiyer',
#        'amhatre', 'bhshetty', 'mudas', 'chandans', 'veerd', 'ebrahim',
#        'sfurtado', 'gsutar', 'bimehta', 'Unknown', 'riskaur'],
#       dtype=object)

# %%
sns.barplot(y="PL",x="Hours",data=df)
# Out:
# <AxesSubplot:xlabel='Hours', ylabel='PL'>

# %% [markdown]
# #### This Graph Visualize us The Hours completed by Pls

# %%
frame=df.groupby("PL")["Username"].value_counts()

# %%
frame
# Out:
# PL       Username
# Unknown  atari        1
#          mohshaik     1
# akrai    sdate       20
#          tkarmoka    20
#          shekadam    19
#                      ..
# veerd    ppadhy       5
#          dangare      4
#          prachauh     4
#          bandare      3
#          surane       3
# Name: Username, Length: 450, dtype: int64

# %%
sns.jointplot(x="Tool Time",y="Idle Time",data=df,kind="scatter")

# %% [markdown]
# #### This Graph Visualize us as the Tool time increases the idle Time increases

# %%
sns.jointplot(x="User Active Time",y="Idle Time",data=df,kind="hex")

# %%
sns.boxplot(df["User Active Time"])
# Out:
# C:\Users\91702\AppData\Roaming\Python\Python37\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='User Active Time'>

# %%
df["User Active Time"].value_counts()
# Out:
# 286.90    5
# 182.43    5
# 289.63    4
# 152.27    4
# 216.02    4
#          ..
# 434.37    1
# 106.10    1
# 366.58    1
# 900.03    1
# 402.45    1
# Name: User Active Time, Length: 10743, dtype: int64

# %%
sns.displot(x="User Active Time",data=df)

# %%
Feature_counts=df.groupby("Username")["Features"].value_counts()

# %%
Feature_counts
# Out:
# Username  Features
# aajadhav  629         1
# aambokar  1,369       1
#           1,525       1
#           1,545       1
#           1,558       1
#                      ..
# zardi     317         1
#           468         1
#           503         1
#           67          1
#           801         1
# Name: Features, Length: 12511, dtype: int64

# %%
sns.jointplot(x="Username",y="Idle Time", data=df)

# %%
df["Rank"] = df["Username"].rank()

# %%
df.head()
# Out:
#          Date     PL  Username @Timestamp per day             Task Name  \
# 0  02-01-2020  parao  rjaiswar         02-01-2020  RWOFSignReviewRepair
# 1  02-01-2020  parao  sakoleka         02-01-2020  RWOFSignReviewRepair
# 2  02-01-2020  parao  nthakull         02-01-2020  RWOFSignReviewRepair
# 3  02-01-2020  parao  rajeyada         02-01-2020  RWOFSignReviewRepair
# 4  02-01-2020  parao  ajayyada         02-01-2020  RWOFSignReviewRepair
#
#    Tool Time  User Active Time  Idle Time  Kms Completed Features  \
# 0     516.92            317.10     199.82          100.5    1,145
# 1     515.40            402.32     113.08          126.5    1,545
# 2     497.35            402.45      94.90          169.5    1,285
# 3     493.90            259.88     234.02          186.6    1,332
# 4     476.43            303.32     173.12          148.0    1,368
#
#    Count of Tiles  Hours    Rank
# 0              25   8.62  8464.0
# 1              33   8.59  9084.0
# ...

# %%
df.to_csv("domain2.csv")

# %%
df['Idle Time'].nlargest(n=5).plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['Tool Time'].nlargest(n=5).plot.bar()
# Out:
# <AxesSubplot:>

# %%
df["Features"]=df['Features'].str.replace(',','',regex=True).astype(float)

# %%
df.head()
# Out:
#          Date     PL  Username @Timestamp per day             Task Name  \
# 0  02-01-2020  parao  rjaiswar         02-01-2020  RWOFSignReviewRepair
# 1  02-01-2020  parao  sakoleka         02-01-2020  RWOFSignReviewRepair
# 2  02-01-2020  parao  nthakull         02-01-2020  RWOFSignReviewRepair
# 3  02-01-2020  parao  rajeyada         02-01-2020  RWOFSignReviewRepair
# 4  02-01-2020  parao  ajayyada         02-01-2020  RWOFSignReviewRepair
#
#    Tool Time  User Active Time  Idle Time  Kms Completed  Features  \
# 0     516.92            317.10     199.82          100.5    1145.0
# 1     515.40            402.32     113.08          126.5    1545.0
# 2     497.35            402.45      94.90          169.5    1285.0
# 3     493.90            259.88     234.02          186.6    1332.0
# 4     476.43            303.32     173.12          148.0    1368.0
#
#    Count of Tiles  Hours    Rank
# 0              25   8.62  8464.0
# 1              33   8.59  9084.0
# ...

# %%
df["Features"].nsmallest(n=10).plot.bar()
# Out:
# <AxesSubplot:>

# %%
df["Task Name"].value_counts()
# Out:
# RWOFSignReviewRepair      7380
# RWOFSignReviewRepairQA    5407
# Name: Task Name, dtype: int64

# %%
df["Task Name"]=pd.get_dummies(df["Task Name"],drop_first=True)

# %%
df["Task Name"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 12782    1
# 12783    1
# 12784    1
# 12785    1
# 12786    1
# Name: Task Name, Length: 12787, dtype: uint8

# %%
df=df.drop(columns=["PL","Username","@Timestamp per day"])

# %%
df
# Out:
#              Date  Task Name  Tool Time  User Active Time  Idle Time  \
# 0      02-01-2020          0     516.92            317.10     199.82
# 1      02-01-2020          0     515.40            402.32     113.08
# 2      02-01-2020          0     497.35            402.45      94.90
# 3      02-01-2020          0     493.90            259.88     234.02
# 4      02-01-2020          0     476.43            303.32     173.12
# ...           ...        ...        ...               ...        ...
# 12782  26-10-2020          1     135.48             49.68      85.80
# 12783  26-10-2020          1       6.45              3.82       2.63
# 12784  27-10-2020          1     417.53            107.33     310.20
# 12785  28-10-2020          1       0.00              0.00       0.00
# 12786  29-10-2020          1      29.05             20.98       8.07
#
#        Kms Completed  Features  Count of Tiles  Hours    Rank
# 0              100.5    1145.0              25   8.62  8464.0
# ...

# %%
df["Date"]=pd.to_datetime(df["Date"])
df['Quarter']=df['Date'].dt.quarter

# %%
df.head()
# Out:
#         Date  Task Name  Tool Time  User Active Time  Idle Time  \
# 0 2020-02-01          0     516.92            317.10     199.82
# 1 2020-02-01          0     515.40            402.32     113.08
# 2 2020-02-01          0     497.35            402.45      94.90
# 3 2020-02-01          0     493.90            259.88     234.02
# 4 2020-02-01          0     476.43            303.32     173.12
#
#    Kms Completed  Features  Count of Tiles  Hours    Rank  Quarter
# 0          100.5    1145.0              25   8.62  8464.0        1
# 1          126.5    1545.0              33   8.59  9084.0        1
# 2          169.5    1285.0              46   8.29  6473.5        1
# 3          186.6    1332.0              49   8.23  8220.0        1
# 4          148.0    1368.0              40   7.94   369.5        1

# %%
df['Quarter'].unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
df['Month'] = pd.DatetimeIndex(df.Date).month

# %%
df['day'] = pd.DatetimeIndex(df.Date).day

# %%
df['year']=pd.DatetimeIndex(df.Date).year

# %%
df=df.drop(columns=["Date"])

# %%
df
# Out:
#        Task Name  Tool Time  User Active Time  Idle Time  Kms Completed  \
# 0              0     516.92            317.10     199.82          100.5
# 1              0     515.40            402.32     113.08          126.5
# 2              0     497.35            402.45      94.90          169.5
# 3              0     493.90            259.88     234.02          186.6
# 4              0     476.43            303.32     173.12          148.0
# ...          ...        ...               ...        ...            ...
# 12782          1     135.48             49.68      85.80            6.1
# 12783          1       6.45              3.82       2.63            3.4
# 12784          1     417.53            107.33     310.20            5.5
# 12785          1       0.00              0.00       0.00            0.0
# 12786          1      29.05             20.98       8.07            8.7
#
#        Features  Count of Tiles  Hours    Rank  Quarter  Month  day  year
# ...

# %% [markdown]
# ### QuarterWise Analysis

# %% [markdown]
# #### Kms Completed Each Quarter

# %%
sns.catplot(x="Quarter",y="Kms Completed",hue='Task Name',data=df,kind="bar")

# %% [markdown]
# #### ACtive Time of user on Task with respect to each Quarter

# %%
sns.catplot(x="Quarter",y="User Active Time",hue="Task Name",data=df,kind="bar")

# %%
#df["user Active Time"]=df.drop(df["User Active Time"]<0)

# %%
index_names1= df[ df['User Active Time']<0 ].index

# %%
index_names1
# Out:
# Int64Index([3701, 3713, 6832, 7345, 9609, 10299, 11620, 11633], dtype='int64')

# %%
index_names1 = df[ df['Tool Time']<0 ].index

# %%
index_names1
# Out:
# Int64Index([], dtype='int64')

# %%
df.drop(index_names1,inplace=True)

# %%
sns.jointplot(x="User Active Time",y="Tool Time",hue="Task Name",data=df,kind="kde")

# %%
#df.to_csv("Tab Data")

# %%
df=df.rename(columns = {'Tool Time':'Tool_Time'})
df=df.rename(columns = {'User Active Time':'Active_Time'})
df=df.rename(columns = {'Idle Time':'Idle_Time'})
df=df.rename(columns = {'Kms Completed':'Kms_completed'})
df=df.rename(columns = {'Count of Tiles':'Count_of_Tile'})

# %%
df.head()
# Out:
#    Task Name  Tool_Time  Active_Time  Idle_Time  Kms_completed  Features  \
# 0          0     516.92       317.10     199.82          100.5    1145.0
# 1          0     515.40       402.32     113.08          126.5    1545.0
# 2          0     497.35       402.45      94.90          169.5    1285.0
# 3          0     493.90       259.88     234.02          186.6    1332.0
# 4          0     476.43       303.32     173.12          148.0    1368.0
#
#    Count_of_Tile  Hours    Rank  Quarter  Month  day  year
# 0             25   8.62  8464.0        1      2    1  2020
# 1             33   8.59  9084.0        1      2    1  2020
# 2             46   8.29  6473.5        1      2    1  2020
# 3             49   8.23  8220.0        1      2    1  2020
# 4             40   7.94   369.5        1      2    1  2020

# %% [markdown]
# ### Detecting Outliers

# %%
sns.distplot(df['Active_Time'])
# Out:
# C:\Users\91702\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Active_Time', ylabel='Density'>

# %%
plt.figure(figsize=(5,10))
plt.hist(x="Active_Time",bins=50,data=df,histtype="bar")
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00,
#         1.000e+00, 2.461e+03, 6.761e+03, 2.980e+03, 4.180e+02, 8.400e+01,
#         2.700e+01, 1.200e+01, 6.000e+00, 7.000e+00, 2.000e+00, 7.000e+00,
#         1.000e+00, 2.000e+00, 1.000e+00, 1.000e+00, 2.000e+00, 2.000e+00,
#         1.000e+00, 1.000e+00, 2.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([-1679.52 , -1458.189, -1236.858, -1015.527,  -794.196,  -572.865,
#          -351.534,  -130.203,    91.128,   312.459,   533.79 ,   755.121,
#           976.452,  1197.783,  1419.114,  1640.445,  1861.776,  2083.107,
#          2304.438,  2525.769,  2747.1  ,  2968.431,  3189.762,  3411.093,
# ...

# %%
sns.distplot(df['Tool_Time'])
# Out:
# C:\Users\91702\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Tool_Time', ylabel='Density'>

# %%
sns.distplot(df['Idle_Time'])
# Out:
# C:\Users\91702\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Idle_Time', ylabel='Density'>

# %%
#### Lets compute the Interquantile range to calculate the boundaries
IQR=df.Tool_Time.quantile(0.75)-df.Tool_Time.quantile(0.25)

# %%
IQR
# Out:
# 287.08

# %%
lower_bridge=df['Tool_Time'].quantile(0.25)-(IQR*1.5)
upper_bridge=df['Tool_Time'].quantile(0.75)+(IQR*1.5)
print(lower_bridge), print(upper_bridge)
# Out:
# -208.12
# 940.2
# (None, None)

# %%
#### Extreme outliers
lower_bridge=df['Tool_Time'].quantile(0.25)-(IQR*3)
upper_bridge=df['Tool_Time'].quantile(0.75)+(IQR*3)
print(lower_bridge), print(upper_bridge)
# Out:
# -638.74
# 1370.82
# (None, None)

# %%
index_names = df[ df['Tool_Time']>1370 ].index

# %%
index_names.value_counts()
# Out:
# 6400     1
# 12460    1
# 6852     1
# 6851     1
# 3010     1
#         ..
# 11602    1
# 6992     1
# 1359     1
# 4428     1
# 2046     1
# Length: 124, dtype: int64

# %%
df.drop(index_names,inplace=True)

# %%
sns.distplot(df['Tool_Time'])
# Out:
# C:\Users\91702\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Tool_Time', ylabel='Density'>

# %%
sns.boxplot(df["Tool_Time"])
# Out:
# C:\Users\91702\AppData\Roaming\Python\Python37\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Tool_Time'>

# %%
IQR1=df.Active_Time.quantile(0.75)-df.Active_Time.quantile(0.25)
IQR1
# Out:
# 204.435

# %%
lower_bridge=df["Active_Time"].quantile(0.25)-(IQR1*1.5)
upper_bridge=df["Active_Time"].quantile(0.75)+(IQR1*1.5)
print(lower_bridge),print(upper_bridge)
# Out:
# -187.72750000000002
# 630.0125
# (None, None)

# %%
lower_bridge=df["Active_Time"].quantile(0.25)-(IQR1*3)
upper_bridge=df["Active_Time"].quantile(0.75)+(IQR1*3)
print(lower_bridge),print(upper_bridge)
# Out:
# -494.38000000000005
# 936.6650000000001
# (None, None)

# %%
Index_names=df[df["Active_Time"]>936].index

# %%
df.drop(Index_names,inplace=True)

# %%
sns.displot(df["Active_Time"])

# %%
df.shape
# Out:
# (12642, 13)

# %%
IQR=df.Idle_Time.quantile(0.75)-df.Idle_Time.quantile(0.25)
IQR
# Out:
# 166.3075

# %%
lower_bridge=df["Idle_Time"].quantile(0.25)-(IQR*1.5)
upper_bridge=df["Idle_Time"].quantile(0.75)+(IQR*1.5)
print(lower_bridge),print(upper_bridge)
# Out:
# -196.16125
# 469.06875
# (None, None)

# %%
lower_bridge=df["Idle_Time"].quantile(0.25)-(IQR*3)
upper_bridge=df["Idle_Time"].quantile(0.75)+(IQR*3)
print(lower_bridge),print(upper_bridge)
# Out:
# -445.6225
# 718.53
# (None, None)

# %%
index_names = df[ df['Idle_Time']>718 ].index

# %%
df.drop(index_names,inplace=True)

# %%
df.shape
# Out:
# (12587, 13)

# %%
sns.displot(df["Idle_Time"])

# %%
df.isnull().sum()
# Out:
# Task Name        0
# Tool_Time        0
# Active_Time      0
# Idle_Time        0
# Kms_completed    0
# Features         0
# Count_of_Tile    0
# Hours            0
# Rank             0
# Quarter          0
# Month            0
# day              0
# year             0
# dtype: int64

# %%
df["Features"]
# Out:
# 0        1145.0
# 1        1545.0
# 2        1285.0
# 3        1332.0
# 4        1368.0
#           ...
# 12782      73.0
# 12783      11.0
# 12784     162.0
# 12785       0.0
# 12786      46.0
# Name: Features, Length: 12587, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

X_scaled=pd.DataFrame(scaler.fit_transform(df),columns=df.columns)

# %%
X_scaled
# Out:
#        Task Name  Tool_Time  Active_Time  Idle_Time  Kms_completed  Features  \
# 0      -0.855893   0.630397     0.568294   0.426951       1.509784  0.119014
# 1      -0.855893   0.623337     1.141547  -0.295933       2.130334  0.632392
# 2      -0.855893   0.539493     1.142421  -0.447443       3.156629  0.298697
# 3      -0.855893   0.523468     0.183390   0.711971       3.564760  0.359019
# 4      -0.855893   0.442319     0.475600   0.204436       2.643481  0.405223
# ...          ...        ...          ...        ...            ...       ...
# 12582   1.168370  -1.141413    -1.230569  -0.523282      -0.743291 -1.256839
# 12583   1.168370  -1.740765    -1.539057  -1.216414      -0.807733 -1.336412
# 12584   1.168370   0.168725    -0.842773   1.346849      -0.757611 -1.142612
# 12585   1.168370  -1.770725    -1.564753  -1.238332      -0.888882 -1.350530
# 12586   1.168370  -1.635786    -1.423627  -1.171078      -0.681236 -1.291492
#
# ...

# %% [markdown]
# ### Dbscan For Outliers

# %%
X_db=X_scaled.iloc[:,[2,4]]

# %%
X_db
# Out:
#        Active_Time  Kms_completed
# 0         0.568294       1.509784
# 1         1.141547       2.130334
# 2         1.142421       3.156629
# 3         0.183390       3.564760
# 4         0.475600       2.643481
# ...            ...            ...
# 12582    -1.230569      -0.743291
# 12583    -1.539057      -0.807733
# 12584    -0.842773      -0.757611
# 12585    -1.564753      -0.888882
# 12586    -1.423627      -0.681236
#
# [12587 rows x 2 columns]

# %%
from sklearn.cluster import DBSCAN
dbscan=DBSCAN(eps=3,min_samples=13)

# %%
model=dbscan.fit(X_db)
labels=model.labels_

# %%
from sklearn import metrics

#identifying the points which makes up our core points
sample_cores=np.zeros_like(labels,dtype=bool)

sample_cores[dbscan.core_sample_indices_]=True

# %%
#Calculating the number of clusters

n_clusters=len(set(labels))- (1 if -1 in labels else 0)
n_clusters
# Out:
# 1

# %%
print(metrics.silhouette_score(X_db,labels))
# Out:
# 0.8932537122920616

# %% [markdown]
# ## KMEANS ALGORITHMS

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=2, random_state=0) 

kmeans.fit(X_scaled)
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[-0.16443704, -0.88187824, -0.76832986, -0.63031765, -0.51133044,
#         -0.72473626, -0.50594437, -0.88188086, -0.0068631 ,  0.04902936,
#          0.02075325,  0.04151837,  0.        ],
#        [ 0.12573106,  0.67429748,  0.58747667,  0.48195044,  0.39097101,
#          0.55414434,  0.38685274,  0.67429948,  0.00524763, -0.0374886 ,
#         -0.01586825, -0.03174558,  0.        ]])

# %%
kmeans.inertia_
# Out:
# 116229.53688321167

# %%
y=df["Kms_completed"]

# %%
labels = kmeans.labels_

# check how many of the samples were correctly labeled
correct_labels = sum(y == labels)

print("Result: %d out of %d samples were correctly labeled." % (correct_labels, y.size))
# Out:
# Result: 14 out of 12587 samples were correctly labeled.

# %%
print('Accuracy score: {0:0.2f}'. format(correct_labels/float(y.size)))
# Out:
# Accuracy score: 0.00

# %%
from sklearn.cluster import KMeans
cs = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 500, n_init = 10, random_state = 0)
    kmeans.fit(X_scaled)
    cs.append(kmeans.inertia_)
plt.plot(range(1, 11), cs)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('CS')
plt.show()

# %%
kmeans = KMeans(n_clusters=8, random_state=0)

kmeans.fit(X_scaled)

# check how many of the samples were correctly labeled
labels = kmeans.labels_

correct_labels = sum(y == labels)
print("Result: %d out of %d samples were correctly labeled." % (correct_labels, y.size))
print('Accuracy score: {0:0.2f}'. format(correct_labels/float(y.size)))
# Out:
# Result: 24 out of 12587 samples were correctly labeled.
# Accuracy score: 0.00

# %%
kmeans = KMeans(n_clusters=9, random_state=0)

kmeans.fit(X_scaled)

# check how many of the samples were correctly labeled
labels = kmeans.labels_

correct_labels = sum(y == labels)
print("Result: %d out of %d samples were correctly labeled." % (correct_labels, y.size))
print('Accuracy score: {0:0.2f}'. format(correct_labels/float(y.size)))
# Out:
# Result: 15 out of 12587 samples were correctly labeled.
# Accuracy score: 0.00

# %%
kmeans = KMeans(n_clusters=5, random_state=0)

kmeans.fit(X_scaled)

# check how many of the samples were correctly labeled
labels = kmeans.labels_

correct_labels = sum(y == labels)
print("Result: %d out of %d samples were correctly labeled." % (correct_labels, y.size))
print('Accuracy score: {0:0.2f}'. format(correct_labels/float(y.size)))
# Out:
# Result: 20 out of 12587 samples were correctly labeled.
# Accuracy score: 0.00

# %%
X=df.iloc[:,[2,4]].values

# %%
wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i, init='k-means++',random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans=KMeans(n_clusters=3,init='k-means++',random_state=0)
y_predict=kmeans.fit_predict(X)

# %%
y_predict
# Out:
# array([0, 2, 2, ..., 1, 1, 1])

# %%
import matplotlib.pyplot as mtp
mtp.scatter(X[y_predict==0,0],X[y_predict==0,1],s=20,c='blue',label='cluster1')
mtp.scatter(X[y_predict==1,0],X[y_predict==1,1],s=20,c='red',label='cluster2')
mtp.scatter(X[y_predict==2,0],X[y_predict==2,1],s=20,c='green',label='cluster3')
#mtp.scatter(X[y_predict==3,0],X[y_predict==3,1],s=20,c='cyan',label='cluster4')
#mtp.scatter(X[y_predict==4,0],X[y_predict==4,1],s=20,c='magenta',label='cluster5')
mtp.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=100,c='yellow',label='centroid')
mtp.title('Cluster of users')
mtp.xlabel('kms Completed')
mtp.ylabel('Active Time')
mtp.legend()
mtp.show()

# %%
from sklearn.metrics import silhouette_score
score = silhouette_score(X, kmeans.labels_, metric='euclidean')

# %%
score
# Out:
# 0.4920674356207585

# %%
kmeans1=KMeans(n_clusters=2,init='k-means++',random_state=0)
y_predict1=kmeans1.fit_predict(X)

# %%
import matplotlib.pyplot as mtp
mtp.scatter(X[y_predict1==0,0],X[y_predict1==0,1],s=20,c='blue',label='cluster1')
mtp.scatter(X[y_predict1==1,0],X[y_predict1==1,1],s=20,c='red',label='cluster2')
#mtp.scatter(X[y_predict1==2,0],X[y_predict1==2,1],s=20,c='green',label='cluster3')
#mtp.scatter(X[y_predict1==3,0],X[y_predict1==3,1],s=20,c='cyan',label='cluster4')
#mtp.scatter(X[y_predict1==4,0],X[y_predict1==4,1],s=20,c='magenta',label='cluster5')
mtp.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=100,c='yellow',label='centroid')
mtp.title('Cluster of users')
mtp.xlabel('kms Completed')
mtp.ylabel('Active Time')
mtp.legend()
mtp.show()

# %%
from sklearn.metrics import silhouette_score,silhouette_samples
score1 = silhouette_score(X, kmeans1.labels_, metric='euclidean')

# %%
score1
# Out:
# 0.5173824613099416

# %%
kmeans2=KMeans(n_clusters=8,init='k-means++',random_state=0)
y_predict2=kmeans2.fit_predict(X)

# %%
import matplotlib.pyplot as mtp
mtp.scatter(X[y_predict2==0,0],X[y_predict2==0,1],s=20,c='blue',label='cluster1')
mtp.scatter(X[y_predict2==1,0],X[y_predict2==1,1],s=20,c='red',label='cluster2')
mtp.scatter(X[y_predict2==2,0],X[y_predict2==2,1],s=20,c='green',label='cluster3')
mtp.scatter(X[y_predict2==3,0],X[y_predict2==3,1],s=20,c='cyan',label='cluster4')
mtp.scatter(X[y_predict2==4,0],X[y_predict2==4,1],s=20,c='magenta',label='cluster5')
mtp.scatter(X[y_predict2==5,0],X[y_predict2==5,1],s=20,c='black',label='cluster6')
mtp.scatter(X[y_predict2==6,0],X[y_predict2==6,1],s=20,c='red',label='cluster7')
mtp.scatter(X[y_predict2==7,0],X[y_predict2==7,1],s=20,c='pink',label='cluster8')
mtp.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=100,c='yellow',label='centroid')
mtp.title('Cluster of users')
mtp.xlabel('kms Completed')
mtp.ylabel('Active Time')
mtp.legend()
mtp.show()

# %%
from sklearn.metrics import silhouette_score
score2= silhouette_score(X, kmeans2.labels_, metric='euclidean')

# %%
score2
# Out:
# 0.41529711252790713

# %%
X1=df.iloc[:,[4,10]].values

# %%
wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i, init='k-means++',random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans=KMeans(n_clusters=6,init='k-means++',random_state=0)
y_kmeans=kmeans.fit_predict(X1)

# %%
y_kmeans
# Out:
# array([2, 1, 1, ..., 0, 0, 0])

# %%
import matplotlib.pyplot as mtp
mtp.scatter(X[y_kmeans==0,0],X[y_kmeans==0,1],s=20,c='blue',label='cluster1')
mtp.scatter(X[y_kmeans==1,0],X[y_kmeans==1,1],s=20,c='red',label='cluster2')
mtp.scatter(X[y_kmeans==2,0],X[y_kmeans==2,1],s=20,c='green',label='cluster3')
mtp.scatter(X[y_kmeans==3,0],X[y_kmeans==3,1],s=20,c='cyan',label='cluster4')
mtp.scatter(X[y_kmeans==4,0],X[y_kmeans==4,1],s=20,c='magenta',label='cluster5')
mtp.scatter(X[y_kmeans==5,0],X[y_kmeans==5,1],s=20,c='pink',label='cluster5')
mtp.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=100,c='yellow',label='centroid')
mtp.title('Cluster of users')
mtp.xlabel('kms Completed')
mtp.ylabel('months')
mtp.legend()
mtp.show()

# %%
from sklearn.metrics import silhouette_score
score3= silhouette_score(X, kmeans.labels_, metric='euclidean')

# %%
score3
# Out:
# 0.03217979872885721

# %%
range_n_clusters=[2,3,4,5,6,7,8,9,10]

# %%
import matplotlib.cm as cm
for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    # 2nd Plot showing the actual clusters formed
    colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(X[:, 0], X[:, 1], marker='.', s=30, lw=0, alpha=0.7,
                c=colors, edgecolor='k')

    # Labeling the clusters
    centers = clusterer.cluster_centers_
    # Draw white circles at cluster centers
    ax2.scatter(centers[:, 0], centers[:, 1], marker='o',
                c="white", alpha=1, s=200, edgecolor='k')

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1,
                    s=50, edgecolor='k')

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')

plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.5173921559125285
# For n_clusters = 3 The average silhouette_score is : 0.4918981399737912
# For n_clusters = 4 The average silhouette_score is : 0.47058698303629853
# For n_clusters = 5 The average silhouette_score is : 0.4375209600387976
# For n_clusters = 6 The average silhouette_score is : 0.4511393666971486
# For n_clusters = 7 The average silhouette_score is : 0.439715966800327
# For n_clusters = 8 The average silhouette_score is : 0.4159017554567213
# For n_clusters = 9 The average silhouette_score is : 0.4306473029802636
# For n_clusters = 10 The average silhouette_score is : 0.41422828860654376

# %% [markdown]
# ### Clustering Our Data

# %%
kmeans=KMeans(n_clusters=6)
kmeans.fit(X_scaled)
# Out:
# KMeans(n_clusters=6)

# %%
cluster=kmeans.predict(X_scaled)

# %%
cluster
# Out:
# array([3, 3, 3, ..., 1, 4, 4])

# %% [markdown]
# ### Principal Component Analysis

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)

# %%
reduced_X=pd.DataFrame(pca.fit_transform(X_scaled),columns=["PC1","PCA"])

# %%
reduced_X
# Out:
#             PC1       PCA
# 0      1.743106 -0.255683
# 1      2.284693  0.136997
# 2      2.619643  0.806922
# 3      2.794329  0.871957
# 4      2.213064  0.442936
# ...         ...       ...
# 12582 -2.570463  1.690434
# 12583 -3.527366  1.860097
# 12584 -0.542034  1.214560
# 12585 -3.605901  1.773531
# 12586 -3.255176  1.830564
#
# [12587 rows x 2 columns]

# %%
reduced_X["cluster"]=cluster
reduced_X
# Out:
#             PC1       PCA  cluster
# 0      1.743106 -0.255683        3
# 1      2.284693  0.136997        3
# 2      2.619643  0.806922        3
# 3      2.794329  0.871957        3
# 4      2.213064  0.442936        3
# ...         ...       ...      ...
# 12582 -2.570463  1.690434        4
# 12583 -3.527366  1.860097        4
# 12584 -0.542034  1.214560        1
# 12585 -3.605901  1.773531        4
# 12586 -3.255176  1.830564        4
#
# [12587 rows x 3 columns]

# %%
sns.displot(reduced_X["cluster"]==4)
# Out:
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
reduced_centers=pca.transform(kmeans.cluster_centers_)

# %%
reduced_centers
# Out:
# array([[ 0.61058032, -1.37317735],
#        [ 0.78704853,  1.28073632],
#        [-2.17989724, -1.05111458],
#        [ 2.24280499,  1.66273884],
#        [-2.23640572,  1.37323188],
#        [ 3.60827462, -1.31866842]])

# %%
plt.figure(figsize=(14,10))
plt.scatter(reduced_X["PC1"],reduced_X["PCA"])


plt.scatter(reduced_X[reduced_X['cluster'] == 0].loc[:, 'PC1'], reduced_X[reduced_X['cluster'] == 0].loc[:, 'PCA'], color='slateblue')
plt.scatter(reduced_X[reduced_X['cluster'] == 1].loc[:, 'PC1'], reduced_X[reduced_X['cluster'] == 1].loc[:, 'PCA'], color='springgreen')
plt.scatter(reduced_X[reduced_X['cluster'] == 2].loc[:, 'PC1'], reduced_X[reduced_X['cluster'] == 2].loc[:, 'PCA'], color='indigo')
plt.scatter(reduced_X[reduced_X['cluster'] == 3].loc[:, 'PC1'], reduced_X[reduced_X['cluster'] == 3].loc[:, 'PCA'], color='teal')
plt.scatter(reduced_X[reduced_X['cluster'] == 4].loc[:, 'PC1'], reduced_X[reduced_X['cluster'] == 4].loc[:, 'PCA'], color='lightcoral')
plt.scatter(reduced_X[reduced_X['cluster'] == 5].loc[:, 'PC1'], reduced_X[reduced_X['cluster'] == 5].loc[:, 'PCA'], color='gold')


plt.scatter(reduced_centers[:,0],reduced_centers[:,1],color="black",s=300)
plt.show()

# %% [markdown]
# ## DBSCAN

# %%
from sklearn.cluster import DBSCAN
dbscan=DBSCAN(eps=2,min_samples=15,metric="euclidean")

# %%
model=dbscan.fit(X)
labels=model.labels_

# %%
from sklearn import metrics

# %%
#identifying the points which makes up our core points
sample_cores=np.zeros_like(labels,dtype=bool)      
sample_cores
# Out:
# array([False, False, False, ..., False, False, False])

# %%
sample_cores[dbscan.core_sample_indices_]=True

# %%
sample_cores
# Out:
# array([False, False, False, ..., False, False, False])

# %%
#Calculating the number of clusters
n_clusters=len(set(labels))- (1 if -1 in labels else 0)
n_clusters
# Out:
# 39

# %%
n_noise_ = list(labels).count(-1)

# %%
n_noise_
# Out:
# 9248

# %%
print(metrics.silhouette_score(X_scaled,labels))
# Out:
# -0.1486088340247204

# %%
print('Estimated number of clusters: %d' % n_clusters)
print('Estimated number of noise points: %d' % n_noise_)
print("Homogeneity: %0.3f" % metrics.homogeneity_score(y, labels))
print("Completeness: %0.3f" % metrics.completeness_score(y, labels))
print("V-measure: %0.3f" % metrics.v_measure_score(y, labels))
print("Adjusted Rand Index: %0.3f"
      % metrics.adjusted_rand_score(y, labels))
print("Adjusted Mutual Information: %0.3f"
      % metrics.adjusted_mutual_info_score(y, labels))
print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(X_scaled, labels))
# Out:
# Estimated number of clusters: 1
# Estimated number of noise points: 1
# Homogeneity: 0.000
# Completeness: 1.000
# V-measure: 0.000
# Adjusted Rand Index: 0.000
# Adjusted Mutual Information: 0.000
# C:\Users\91702\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\cluster\_supervised.py:58: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and binary values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\91702\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\cluster\_supervised.py:58: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and binary values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\91702\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\cluster\_supervised.py:58: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and binary values for target
# ...

# %% [markdown]
# ## Hirarchical Cluster

# %%
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(10, 7))
plt.title(" Dendograms")
dend = shc.dendrogram(shc.linkage(X_scaled, method='ward'))

# %%
#training the hierarchical model on dataset  
from sklearn.cluster import AgglomerativeClustering  
hc= AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')  
y_pred= hc.fit_predict(X)

# %%
y_pred
# Out:
# array([0, 1, 1, ..., 2, 2, 2], dtype=int64)

# %%
#visulaizing the clusters  
mtp.scatter(X[y_pred == 0, 0], X[y_pred == 0, 1], s = 100, c = 'blue', label = 'Cluster 1')  
mtp.scatter(X[y_pred == 1, 0], X[y_pred == 1, 1], s = 100, c = 'green', label = 'Cluster 2')  
mtp.scatter(X[y_pred== 2, 0],  X[y_pred == 2, 1], s = 100, c = 'red', label = 'Cluster 3')  
#mtp.scatter(X[y_pred == 3, 0], X[y_pred == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')  
#mtp.scatter(X[y_pred == 4, 0], X[y_pred == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')  
mtp.title('Clusters of users')  
mtp.xlabel('user Active Time')  
mtp.ylabel('kms completed')  
mtp.legend()  
mtp.show()

# %%
print(metrics.silhouette_score(X,y_pred))
# Out:
# 0.4121676305436188

# %% [markdown]
# ### Hierarchy PCA

# %%
reduced_X=reduced_X.drop(columns="cluster")

# %%
reduced_X
# Out:
#             PC1       PCA
# 0      1.743106 -0.255683
# 1      2.284693  0.136997
# 2      2.619643  0.806922
# 3      2.794329  0.871957
# 4      2.213064  0.442936
# ...         ...       ...
# 12582 -2.570463  1.690434
# 12583 -3.527366  1.860097
# 12584 -0.542034  1.214560
# 12585 -3.605901  1.773531
# 12586 -3.255176  1.830564
#
# [12587 rows x 2 columns]

# %%
import scipy.cluster.hierarchy as shc
plt.figure(figsize =(6, 6)) 
plt.title('Visualising the data') 
Dendrogram = shc.dendrogram((shc.linkage(reduced_X, method ='ward')))

# %%
silhouette_scores = [] 

for n_cluster in range(2, 8):
    silhouette_scores.append( 
        silhouette_score(reduced_X, AgglomerativeClustering(n_clusters = n_cluster).fit_predict(reduced_X))) 
    
# Plotting a bar graph to compare the results 
k = [2, 3, 4, 5, 6,7] 
plt.bar(k, silhouette_scores) 
plt.xlabel('Number of clusters', fontsize = 10) 
plt.ylabel('Silhouette Score', fontsize = 10) 
plt.show()

# %%
agg = AgglomerativeClustering(n_clusters=2)
agg.fit(reduced_X)
# Out:
# AgglomerativeClustering()

# %%
# Visualizing the clustering 
plt.scatter(reduced_X['PC1'],reduced_X['PCA'],  
           c = AgglomerativeClustering(n_clusters = 3).fit_predict(reduced_X), cmap =plt.cm.winter) 
plt.show()

# %% [markdown]
# ## DBSCAN PRACTISE

# %%
from sklearn.preprocessing import normalize  
X_normalized = normalize(X_scaled)  
# Now we will convert numpy arrays in the dataset into dataframes of panda  
X_normalized = pd.DataFrame(X_normalized)

# %%
X_normalized
# Out:
#              0         1         2         3         4         5         6   \
# 0     -0.257993  0.190022  0.171302  0.128697  0.455096  0.035875  0.408352
# 1     -0.206486  0.150381  0.275400 -0.071394  0.513947  0.152566  0.499281
# 2     -0.162212  0.102247  0.216516 -0.084801  0.598257  0.056610  0.612381
# 3     -0.152078  0.093011  0.032585  0.126505  0.633398  0.063792  0.621752
# 4     -0.178555  0.092276  0.099219  0.042649  0.551477  0.084537  0.562231
# ...         ...       ...       ...       ...       ...       ...       ...
# 12582  0.298574 -0.291685 -0.314469 -0.133723 -0.189946 -0.321182 -0.201832
# 12583  0.253566 -0.377791 -0.334015 -0.263993 -0.175299 -0.290036 -0.171407
# 12584  0.305945  0.044182 -0.220685  0.352680 -0.198385 -0.299200 -0.206814
# 12585  0.247170 -0.374599 -0.331026 -0.261971 -0.188044 -0.285707 -0.167084
# 12586  0.252291 -0.353223 -0.307410 -0.252876 -0.147102 -0.278878 -0.112661
#
# ...

# %%
# Initializing a variable with the PCA() function  
pcaFD = PCA(n_components = 2) # components of data  
# Transforming the normalized data with PCA  
M_principal = pcaFD.fit_transform(X_normalized)  
# Making dataframes from the transformed data  
M_principal = pd.DataFrame(M_principal)  
# Creating two columns in the transformed data  
M_principal.columns = ['C1', 'C2']  
# Printing the head of the transformed data  
print(M_principal.head())
# Out:
#          C1        C2
# 0  0.549827 -0.152093
# 1  0.573768 -0.070261
# 2  0.512817  0.022287
# 3  0.512714  0.030203
# 4  0.478861 -0.022722

# %%
# Creating clustering model of the data using the DBSCAN function and providing parameters in it  
db_default = DBSCAN(eps = 0.0375, min_samples = 30).fit(M_principal)  
# Labelling the clusters we have created in the dataset  
labeling = db_default.labels_

# %%
# !pip install cvec
